# %% [markdown]
# # Introduction to modeling
# Step by step
#
# Initial conditions
# Boundary conditions
# Variables
# Auxiliary variables
#
# Physical knowledge is important
#
# Drawing is important
#
# Python vs. Coach vs. C++ vs...
#
# Python vs. Coach vs. C++ vs...

# %% [markdown]
# # Introduction to Modeling
#
# In physics, we use models to understand, predict, and simulate reality. A model is a simplified representation of the real world — designed to help us grasp complex systems. Think of the motion of a falling apple, the weather, or the behavior of an electron in a magnetic field.
#
# Modeling is not just mathematics. It’s a creative and critical process where physical knowledge, computational power, and logic come together.
#
# A good model is built in clear steps:
# 1. Initial conditions
#
# These are the starting values of your system. For example: a ball starts at a height of 2.0 m with a velocity of 0 m/s. These values are essential for a simulation: they determine how the system evolves from the beginning.
# 2. Boundary conditions
#
# Boundary conditions specify what happens at the 'edges' of your model. For example:
#
#     A spring can stretch a maximum of 10 cm.
#
#     An object stops at the wall.
#
#     There is no friction outside a certain area.
#
# They constrain your model and ensure your simulation remains realistic.
# 3. Variables
#
# Variables describe the state of the system at any given moment, for example:
#
#     position x
#
#     velocity v
#
#     time t
#
# These change continuously during the simulation.
# 4. Auxiliary variables
#
# Sometimes you need extra variables that don’t directly describe the state, but are necessary for your calculations. Think of:
#
#     acceleration a as the derivative of v
#
#     force F = m·a
#
#     intermediate results like delta_v or energy
#
# These make your code and reasoning clearer and more reusable.
#
# A model is only as good as the physical assumptions it’s based on:
#
#     What forces are acting?
#
#     Can you ignore air resistance?
#
#     Does Newton’s second law apply here?
#
# Without solid physical insight, a model can be misleading or wrong, even if the code runs perfectly.
#
# A sketch or diagram of the situation is not a luxury — it’s an essential part of modeling. Drawing forces you to:
#
#     Visualize the forces
#
#     Clarify what you’re modeling (and what you’re leaving out)
#
#     Link your variables visually to reality
#
# Modeling without drawing is like building without a blueprint.
#
# There are various tools and languages you can use to create models and run simulations:
#
# | Tool/Language | Advantages                                                                                           | Disadvantages                                         |
# | ------------- | --------------------------------------------------------------------------------------------------- | ----------------------------------------------------- |
# | **Python**    | Accessible, powerful, many libraries (like `matplotlib`, `numpy`). Great for custom simulations.    | Requires some programming experience                  |
# | **Coach**     | Intuitive interface, good for experiments and direct feedback.                                      | Less flexible, harder to adapt for complex models     |
# | **C++**       | Fast, suitable for large and heavy simulations.                                                     | Complex syntax, not beginner-friendly                 |
# | **Excel**     | Good for simple numerical models, easy to start with.                                               | Limited scalability and repeatability                 |
#
# For this course, we use Python because it offers a good balance between accessibility and flexibility. You’ll learn not only modeling, but also programming — two skills that are increasingly important in physics.
